# %% [markdown]
# # Welcome to the NLP Exercise
#
# For this exercise, we will use the the Blog Authorship Corpus, originally from Kaggle, modified and provided with this notebook. This notebook will serve as a template for you to complete the four phases of your project: Data Loading, Data Exploration, Modeling, and Evaluation.
#
# NOTE: Any portion of the prompt labeled "BONUS POINTS" is not required. We do not expect a candidate to be an expert in the concepts required for every BONUS POINTS section, but we've included them to allow candidates with related skills to be recognized.

# %% [markdown]
# # Data Loading
#
# The dataset is stored as a zipped file: data.zip. Upon unzipping using the following cell, you should have a directory, ./data/, with two subdirectories ./data/docs/ and ./data/meta-data/. Each file within the ./data/docs/ directory has an identical structure, one document per line, with a unique id prepended to the line, separated by a tab character "\t"
#
# Example:
#
# "8463   'This is an example, albeit very boring, blog post.'"
#
# The metadata files in ./data/meta-data/ are standard CSV's.

# %%
# Run this cell to unzip the data directory into your Colab environment
# !unzip nlp_exercise/data.zip

# %% [markdown]
# # Data Exploration
#
# Please generate summary statistics on both the text and meta-data fields to help aid in the understanding of the input data. Use appropriate data visualization techniques to demonstrate your findings.

# %% [markdown]
# # Modeling
#
# Create a classifier that takes a blog's text as input and predicts the topic of the text using the "topic" column as your dependent variable. You are free to use any feature transformation and/or dimensionality reduction methods, and any statistical or machine learning algorithm, to create your classification model. HINT: We are hoping to see HOW you tackle problems, not just the final output.
#
# If your final model was trained on GPU, and/or your model takes significant time to run inference on CPU only, then create a second model that runs more quickly.
#
# ### BONUS POINTS:
# 1. Discuss trade-offs between complex and simpler models concerning predictive power/performance, explainability, and computational complexity.
# 2. Compare inference times and performance between your candidate models and discuss the differences.

# %% [markdown]
# # Evaluation
#
# Calculate performance metrics for your chosen model(s).
#
# ### BONUS POINTS:
# 1. Describe your choice of performance metric(s) used for model selection.
# 2. Use an appropriate global or local AI-Explainability technique to describe your model further.

# %% [markdown]
# # BONUS POINTS: Deployment
#
# Create an interactive visualization, application, or dashboard, that further aids understanding or otherwise enhances the useability of the model.
